# %% [markdown]
# # Great Expectations Task

# %% [markdown]
# ## 1. Install Great Expectations Library

# %%
# If not already installed, uncomment and run:
# !pip install great_expectations==0.15.50
# Out:
# Collecting great_expectations==0.15.50
#   Downloading great_expectations-0.15.50-py3-none-any.whl.metadata (10 kB)
# Collecting altair<4.2.1,>=4.0.0 (from great_expectations==0.15.50)
#   Downloading altair-4.2.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Click>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (8.1.8)
# Collecting colorama>=0.4.3 (from great_expectations==0.15.50)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (43.0.3)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (8.6.1)
# Requirement already satisfied: Ipython>=7.16.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.1.6)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.23.0)
# Collecting makefun<2,>=1.7.0 (from great_expectations==0.15.50)
#   Downloading makefun-1.15.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.1.3)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (6.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (24.2)
# Collecting pydantic<2.0,>=1.10.4 (from great_expectations==0.15.50)
#   Downloading pydantic-1.10.21-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2025.1)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.32.3)
# Collecting ruamel.yaml<0.17.18,>=0.16 (from great_expectations==0.15.50)
#   Downloading ruamel.yaml-0.17.17-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.14.1)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (4.12.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (5.3.1)
# Collecting urllib3<1.27,>=1.25.4 (from great_expectations==0.15.50)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.15.50) (2.1.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations==0.15.50) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair<4.2.1,>=4.0.0->great_expectations==0.15.50) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.2->great_expectations==0.15.50) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=1.7.0->great_expectations==0.15.50) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (75.1.0)
# Collecting jedi>=0.16 (from Ipython>=7.16.3->great_expectations==0.15.50)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.15.50) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.15.50) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10->great_expectations==0.15.50) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch>=1.22->great_expectations==0.15.50) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.15.50) (0.23.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.15.50) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.15.50) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (23.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (6.1.12)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.15.50) (1.2.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->great_expectations==0.15.50) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->great_expectations==0.15.50) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.15.50) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations==0.15.50) (2.22)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.15.50) (1.8.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.15.50) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations==0.15.50) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations==0.15.50) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations==0.15.50) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations==0.15.50) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.4.10->great_expectations==0.15.50) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations==0.15.50) (2.6)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.15.50) (1.3.1)
# Downloading great_expectations-0.15.50-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 44.1 MB/s eta 0:00:00
# Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 26.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading makefun-1.15.6-py2.py3-none-any.whl (22 kB)
# Downloading pydantic-1.10.21-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.1 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 5.0 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 8.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.8 MB/s eta 0:00:00
# Installing collected packages: makefun, urllib3, ruamel.yaml, pydantic, jedi, colorama, altair, great_expectations
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.18.10
#     Uninstalling ruamel.yaml-0.18.10:
#       Successfully uninstalled ruamel.yaml-0.18.10
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: altair
#     Found existing installation: altair 4.2.2
#     Uninstalling altair-4.2.2:
#       Successfully uninstalled altair-4.2.2
#   Attempting uninstall: great_expectations
#     Found existing installation: great-expectations 1.3.11
#     Uninstalling great-expectations-1.3.11:
#       Successfully uninstalled great-expectations-1.3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.19.8 requires pydantic<3,>=2.6, but you have pydantic 1.10.21 which is incompatible.
# langchain-core 0.3.47 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.21 which is incompatible.
# albumentations 2.0.5 requires pydantic>=2.9.2, but you have pydantic 1.10.21 which is incompatible.
# langchain 0.3.21 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.21 which is incompatible.
# google-genai 1.7.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.21 which is incompatible.
# Successfully installed altair-4.2.0 colorama-0.4.6 great_expectations-0.15.50 jedi-0.19.2 makefun-1.15.6 pydantic-1.10.21 ruamel.yaml-0.17.17 urllib3-1.26.20

# %% [markdown]
# ##2. Import Necessary Libraries

# %%
import great_expectations as gx
import pandas as pd
import numpy as np

# %% [markdown]
# ##3. Load Labels.csv

# %%
# If the file is in your Google Drive, make sure you mount Drive first:
# from google.colab import drive
# drive.mount('/content/drive')

# Adjust the path to your CSV file accordingly
df = pd.read_csv("Labels.csv")

# %% [markdown]
# ##4. Preview the Dataset

# %%
# Look at the first 5 rows
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# 0          B_001.png         C_001.png                          593
# 1          B_002.png         C_002.png                          579
# 2          B_003.png         C_003.png                          854
# 3          B_004.png         C_004.png                          549
# 4          B_005.png         C_005.png                          524
#
#    pedestrianLocationY_TopLeft  pedestrianLocationX_BottomRight  \
# 0                          361                              610
# 1                          368                              594
# 2                          720                              854
# 3                          368                              567
# 4                          368                              537
#
#    pedestrianLocationY_BottomRight
# 0                              410
# 1                              415
# 2                              720
# 3                              425
# 4                              413

# %% [markdown]
# ##5. Set Up Great Expectations Context and Data Source

# %%
import great_expectations as gx

# Initialize a DataContext using the new API
context = gx.get_context()
# Out:
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmp8k8w2jf4' for ephemeral docs site

# %% [markdown]
# ##6. Define and Create a Data Batch

# %%
from great_expectations.core.batch import RuntimeBatchRequest

# Create a RuntimeBatchRequest to wrap your existing DataFrame
batch_request = RuntimeBatchRequest(
    datasource_name="my_pandas_datasource",          # Your previously added datasource name
    data_connector_name="default_runtime_data_connector_name",  # Your connector name
    data_asset_name="my_data_asset",                   # An arbitrary asset name
    runtime_parameters={"batch_data": df},            # Your loaded DataFrame
    batch_identifiers={"default_identifier": "default_identifier"}
)

# Print the batch_request to confirm it's created
print(batch_request)
# Out:
# {
#   "datasource_name": "my_pandas_datasource",
#   "data_connector_name": "default_runtime_data_connector_name",
#   "data_asset_name": "my_data_asset",
#   "runtime_parameters": {
#     "batch_data": "<class 'pandas.core.frame.DataFrame'>"
#   },
#   "batch_identifiers": {
#     "default_identifier": "default_identifier"
#   }
# }

# %% [markdown]
# ##7. Define Three Expectations for Column Values

# %% [markdown]
# Using this [link](https://greatexpectations.io/expectations/), choose three expectation functions and apply them to the labels dataset in a relevant manner.
#
# You should replace the 'ExpectColumnValuesToBeBetween' function with other functions you select from the link.
#
# You can also check the format/parameters required of each function when you click "See more" on the function.

# %%
# Expectation 1: "Car1_Location_X" values should be between 0 and 1000
validator.expect_column_values_to_be_between(
    column="Car1_Location_X",
    min_value=0,
    max_value=1000
)

# Expectation 2: "Car1_Label" values should be unique
validator.expect_column_values_to_be_unique(
    column="Car1_Label"
)

# Expectation 3: "Car1_Location_Y" values should not be null
validator.expect_column_values_to_not_be_null(
    column="Car1_Location_Y"
)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py:1477: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py:1477: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidMetricAccessorDomainKwargsKeyError Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/great_expectations/execution_engine/execution_engine.py in _process_direct_and_bundled_metric_computation_configurations(self, metric_fn_direct_configurations, metric_fn_bundle_configurations)
#     554                     metric_computation_configuration.metric_configuration.id
# --> 555                 ] = metric_computation_configuration.metric_fn(
#     556                     **metric_computation_configuration.metric_provider_kwargs
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/expectations/metrics/metric_provider.py in inner_func(*args, **kwargs)
#      89         def inner_func(*args, **kwargs):
# ---> 90             return metric_fn(*args, **kwargs)
#      91
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/expectations/metrics/map_metric_provider.py in inner_func(cls, execution_engine, metric_domain_kwargs, metric_value_kwargs, metrics, runtime_configuration)
#     359
# --> 360                 column_name = get_dbms_compatible_column_names(
#     361                     column_names=column_name,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/expectations/metrics/util.py in get_dbms_compatible_column_names(column_names, batch_columns_list, error_message_template)
#     672     ] = (
# --> 673         _verify_column_names_exist_and_get_normalized_typed_column_names_map(
#     674             column_names=column_names,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/expectations/metrics/util.py in _verify_column_names_exist_and_get_normalized_typed_column_names_map(column_names, batch_columns_list, error_message_template, verify_only)
#     751         if normalized_column_name_mapping is None:
# --> 752             raise gx_exceptions.InvalidMetricAccessorDomainKwargsKeyError(
#     753                 message=error_message_template.format(column_name=column_name)
#
# InvalidMetricAccessorDomainKwargsKeyError: Error: The column "Car1_Label" in BatchData does not exist.
#
# The above exception was the direct cause of the following exception:
#
# MetricResolutionError                     Traceback (most recent call last)
# <ipython-input-15-81e28653e094> in <cell line: 0>()
#       7
#       8 # Expectation 2: "Car1_Label" values should be unique
# ----> 9 validator.expect_column_values_to_be_unique(
#      10     column="Car1_Label"
#      11 )
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validator.py in inst_expectation(*args, **kwargs)
#     604                     )
#     605                 else:
# --> 606                     raise err
#     607
#     608             if self._include_rendered_content:
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validator.py in inst_expectation(*args, **kwargs)
#     567                     )
#     568                 else:
# --> 569                     validation_result = expectation.validate(
#     570                         validator=self,
#     571                         evaluation_parameters=self._expectation_suite.evaluation_parameters,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py in validate(self, validator, configuration, evaluation_parameters, interactive_evaluation, data_context, runtime_configuration)
#    1261         expectation_validation_result_list: list[
#    1262             ExpectationValidationResult
# -> 1263         ] = validator.graph_validate(
#    1264             configurations=[configuration],
#    1265             runtime_configuration=runtime_configuration,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validator.py in graph_validate(self, configurations, runtime_configuration)
#    1055                 return evrs
#    1056             else:
# -> 1057                 raise err
#    1058
#    1059         configuration: ExpectationConfiguration
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validator.py in graph_validate(self, configurations, runtime_configuration)
#    1034                 evrs,
#    1035                 processed_configurations,
# -> 1036             ) = self._resolve_suite_level_graph_and_process_metric_evaluation_errors(
#    1037                 graph=graph,
#    1038                 runtime_configuration=runtime_configuration,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validator.py in _resolve_suite_level_graph_and_process_metric_evaluation_errors(self, graph, runtime_configuration, expectation_validation_graphs, evrs, processed_configurations, show_progress_bars)
#    1193             resolved_metrics,
#    1194             aborted_metrics_info,
# -> 1195         ) = self._metrics_calculator.resolve_validation_graph(
#    1196             graph=graph,
#    1197             runtime_configuration=runtime_configuration,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/metrics_calculator.py in resolve_validation_graph(self, graph, runtime_configuration, min_graph_edges_pbar_enable)
#     266             Dict[str, Union[MetricConfiguration, Set[ExceptionInfo], int]],
#     267         ]
# --> 268         resolved_metrics, aborted_metrics_info = graph.resolve(
#     269             runtime_configuration=runtime_configuration,
#     270             min_graph_edges_pbar_enable=min_graph_edges_pbar_enable,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validation_graph.py in resolve(self, runtime_configuration, min_graph_edges_pbar_enable, show_progress_bars)
#     198             Tuple[str, str, str],
#     199             Dict[str, Union[MetricConfiguration, Set[ExceptionInfo], int]],
# --> 200         ] = self._resolve(
#     201             metrics=resolved_metrics,
#     202             runtime_configuration=runtime_configuration,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validation_graph.py in _resolve(self, metrics, runtime_configuration, min_graph_edges_pbar_enable, show_progress_bars)
#     304                             }
#     305                 else:
# --> 306                     raise err
#     307             except Exception as e:
#     308                 if catch_exceptions:
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/validator/validation_graph.py in _resolve(self, metrics, runtime_configuration, min_graph_edges_pbar_enable, show_progress_bars)
#     274                 # Access "ExecutionEngine.resolve_metrics()" method, to resolve missing "MetricConfiguration" objects.
#     275                 metrics.update(
# --> 276                     self._execution_engine.resolve_metrics(
#     277                         metrics_to_resolve=computable_metrics,
#     278                         metrics=metrics,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/execution_engine/execution_engine.py in resolve_metrics(self, metrics_to_resolve, metrics, runtime_configuration)
#     288             runtime_configuration=runtime_configuration,
#     289         )
# --> 290         return self._process_direct_and_bundled_metric_computation_configurations(
#     291             metric_fn_direct_configurations=metric_fn_direct_configurations,
#     292             metric_fn_bundle_configurations=metric_fn_bundle_configurations,
#
# /usr/local/lib/python3.11/dist-packages/great_expectations/execution_engine/execution_engine.py in _process_direct_and_bundled_metric_computation_configurations(self, metric_fn_direct_configurations, metric_fn_bundle_configurations)
#     557                 )
#     558             except Exception as e:
# --> 559                 raise gx_exceptions.MetricResolutionError(
#     560                     message=str(e),
#     561                     failed_metrics=(
#
# MetricResolutionError: Error: The column "Car1_Label" in BatchData does not exist.

# %% [markdown]
# ### Expectation 1

# %%
# Write code here
# Expectation 1: Ensure "Car1_Location_X" values are between 0 and 1000
validator.expect_column_values_to_be_between(
    column="Car1_Location_X",
    min_value=0,
    max_value=1000
)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py:1477: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "Car1_Location_X",
#       "min_value": 0,
#       "max_value": 1000,
#       "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 121,
#     "unexpected_percent": 100.0,
#     "partial_unexpected_list": [
#       -51.40297655,
#       -53.81963722,
#       -50.23914439,
#       -53.70722021,
#       -52.05372109,
#       -53.93975603,
#       -50.30258412,
#       -53.17447194,
#       -52.72667437,
#       -50.18179353,
#       -52.40699613,
#       -52.38122971,
#       -53.01906414,
#       -50.85034015,
#       -51.93070037,
#       -50.75051989,
#       -50.63015195,
#       -50.69818291,
#       -51.95966168,
#       -50.88663347
#     ],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 100.0,
#     "unexpected_percent_nonmissing": 100.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 1

# %%
# Write code here
# Validate Expectation 1
print("Validation Result for Expectation 1:")
result1 = validator.validate()
print(result1)
# Out:
# Validation Result for Expectation 1:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": false,
#   "results": [
#     {
#       "success": false,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "Car1_Location_X",
#           "min_value": 0,
#           "max_value": 1000,
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 121,
#         "unexpected_percent": 100.0,
#         "partial_unexpected_list": [
#           -51.40297655,
#           -53.81963722,
#           -50.23914439,
#           -53.70722021,
#           -52.05372109,
#           -53.93975603,
#           -50.30258412,
#           -53.17447194,
#           -52.72667437,
#           -50.18179353,
#           -52.40699613,
#           -52.38122971,
#           -53.01906414,
#           -50.85034015,
#           -51.93070037,
#           -50.75051989,
#           -50.63015195,
#           -50.69818291,
#           -51.95966168,
#           -50.88663347
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 100.0,
#         "unexpected_percent_nonmissing": 100.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "evaluation_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 1,
#     "successful_expectations": 0,
#     "unsuccessful_expectations": 1,
#     "success_percent": 0.0
#   },
#   "meta": {
#     "great_expectations_version": "0.15.50",
#     "expectation_suite_name": "my_suite",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-03-25T23:18:20.754025+00:00"
#     },
#     "batch_spec": {
#       "data_asset_name": "my_data_asset",
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250325T230028.017960Z",
#       "pandas_data_fingerprint": "6e4b747422364d9dc4dc4ea0a2a999d5"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_pandas_datasource",
#       "data_connector_name": "default_runtime_data_connector_name",
#       "data_asset_name": "my_data_asset",
#       "batch_identifiers": {
#         "default_identifier": "default_identifier"
#       }
#     },
#     "validation_time": "20250325T231820.753855Z",
#     "checkpoint_name": null
#   }
# }

# %% [markdown]
# ### Expectation 2

# %%
# Write code here
# Expectation 2: "Timestamp" values should be unique
validator.expect_column_values_to_be_unique(
    column="Timestamp"
)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py:1477: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "column": "Timestamp",
#       "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 2

# %%
# Write code here
# Validate Expectation 2
print("Validation Result for Expectation 2:")
result2 = validator.validate()
print(result2)
# Out:
# Validation Result for Expectation 2:
# Calculating Metrics:   0%|          | 0/13 [00:00<?, ?it/s]
# {
#   "success": false,
#   "results": [
#     {
#       "success": false,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "Car1_Location_X",
#           "min_value": 0,
#           "max_value": 1000,
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 121,
#         "unexpected_percent": 100.0,
#         "partial_unexpected_list": [
#           -51.40297655,
#           -53.81963722,
#           -50.23914439,
#           -53.70722021,
#           -52.05372109,
#           -53.93975603,
#           -50.30258412,
#           -53.17447194,
#           -52.72667437,
#           -50.18179353,
#           -52.40699613,
#           -52.38122971,
#           -53.01906414,
#           -50.85034015,
#           -51.93070037,
#           -50.75051989,
#           -50.63015195,
#           -50.69818291,
#           -51.95966168,
#           -50.88663347
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 100.0,
#         "unexpected_percent_nonmissing": 100.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "column": "Timestamp",
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "evaluation_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 1,
#     "unsuccessful_expectations": 1,
#     "success_percent": 50.0
#   },
#   "meta": {
#     "great_expectations_version": "0.15.50",
#     "expectation_suite_name": "my_suite",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-03-25T23:19:51.605850+00:00"
#     },
#     "batch_spec": {
#       "data_asset_name": "my_data_asset",
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250325T230028.017960Z",
#       "pandas_data_fingerprint": "6e4b747422364d9dc4dc4ea0a2a999d5"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_pandas_datasource",
#       "data_connector_name": "default_runtime_data_connector_name",
#       "data_asset_name": "my_data_asset",
#       "batch_identifiers": {
#         "default_identifier": "default_identifier"
#       }
#     },
#     "validation_time": "20250325T231951.605725Z",
#     "checkpoint_name": null
#   }
# }

# %% [markdown]
# ### Expectation 3

# %%
# Clean column names to remove spaces
df.columns = df.columns.str.strip()

# %%
# New Expectation 3: "Car2_Location_X" should be between 0 and 1000
validator.expect_column_values_to_be_between(
    column="Car2_Location_X",
    min_value=0,
    max_value=1000
)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/great_expectations/expectations/expectation.py:1477: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": false,
#   "expectation_config": {
#     "expectation_type": "expect_column_values_to_be_between",
#     "kwargs": {
#       "column": "Car2_Location_X",
#       "min_value": 0,
#       "max_value": 1000,
#       "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#     },
#     "meta": {}
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 121,
#     "unexpected_percent": 100.0,
#     "partial_unexpected_list": [
#       -59.32026969,
#       -59.19656815,
#       -56.74447887,
#       -57.30938047,
#       -59.54589734,
#       -55.77204855,
#       -54.76172465,
#       -54.03136206,
#       -58.77132264,
#       -55.4792791,
#       -58.32106842,
#       -59.28873328,
#       -57.68918188,
#       -55.31382382,
#       -54.68581524,
#       -55.51285632,
#       -57.18588618,
#       -57.93300469,
#       -59.74619673,
#       -59.74590219
#     ],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 100.0,
#     "unexpected_percent_nonmissing": 100.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Validate Data Against Expectation 3

# %%
# Write code here
# Validate
print("Validation Result for Expectation 3 (Car2_Location_X):")
result3 = validator.validate()
print(result3)
# Out:
# Validation Result for Expectation 3 (Car2_Location_X):
# Calculating Metrics:   0%|          | 0/18 [00:00<?, ?it/s]
# {
#   "success": false,
#   "results": [
#     {
#       "success": false,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "Car1_Location_X",
#           "min_value": 0,
#           "max_value": 1000,
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 121,
#         "unexpected_percent": 100.0,
#         "partial_unexpected_list": [
#           -51.40297655,
#           -53.81963722,
#           -50.23914439,
#           -53.70722021,
#           -52.05372109,
#           -53.93975603,
#           -50.30258412,
#           -53.17447194,
#           -52.72667437,
#           -50.18179353,
#           -52.40699613,
#           -52.38122971,
#           -53.01906414,
#           -50.85034015,
#           -51.93070037,
#           -50.75051989,
#           -50.63015195,
#           -50.69818291,
#           -51.95966168,
#           -50.88663347
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 100.0,
#         "unexpected_percent_nonmissing": 100.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_unique",
#         "kwargs": {
#           "column": "Timestamp",
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "expectation_type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "Car2_Location_X",
#           "min_value": 0,
#           "max_value": 1000,
#           "batch_id": "c74d5a16eef4c7b627dbb5a322b6018b"
#         },
#         "meta": {}
#       },
#       "result": {
#         "element_count": 121,
#         "unexpected_count": 121,
#         "unexpected_percent": 100.0,
#         "partial_unexpected_list": [
#           -59.32026969,
#           -59.19656815,
#           -56.74447887,
#           -57.30938047,
#           -59.54589734,
#           -55.77204855,
#           -54.76172465,
#           -54.03136206,
#           -58.77132264,
#           -55.4792791,
#           -58.32106842,
#           -59.28873328,
#           -57.68918188,
#           -55.31382382,
#           -54.68581524,
#           -55.51285632,
#           -57.18588618,
#           -57.93300469,
#           -59.74619673,
#           -59.74590219
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 100.0,
#         "unexpected_percent_nonmissing": 100.0
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "evaluation_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 3,
#     "successful_expectations": 1,
#     "unsuccessful_expectations": 2,
#     "success_percent": 33.33333333333333
#   },
#   "meta": {
#     "great_expectations_version": "0.15.50",
#     "expectation_suite_name": "my_suite",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-03-25T23:23:58.190167+00:00"
#     },
#     "batch_spec": {
#       "data_asset_name": "my_data_asset",
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250325T230028.017960Z",
#       "pandas_data_fingerprint": "6e4b747422364d9dc4dc4ea0a2a999d5"
#     },
#     "active_batch_definition": {
#       "datasource_name": "my_pandas_datasource",
#       "data_connector_name": "default_runtime_data_connector_name",
#       "data_asset_name": "my_data_asset",
#       "batch_identifiers": {
#         "default_identifier": "default_identifier"
#       }
#     },
#     "validation_time": "20250325T232358.189803Z",
#     "checkpoint_name": null
#   }
# }
